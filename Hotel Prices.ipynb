# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %matplotlib inline
import plotly.graph_objects as go
import folium
import plotly.express as px
import pandas as pd

# %%
df=pd.read_csv("../input/hotel-prices-beginner-dataset/hotels.csv")

# %%
df.head()
# Out:
#      Profit  Price in Millions  Square Meter     City
# 0  119000.0              21.88        3938.0   Berlin
# 1  250000.0              27.95        3986.0   Munich
# 2  250000.0              16.09        2574.0  Cologne
# 3  145000.0              27.58        4155.0   Munich
# 4  110000.0              23.76        3795.0   Berlin

# %%
df.isna().sum()
# Out:
# Profit               0
# Price in Millions    0
# Square Meter         0
# City                 0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Profit             150 non-null    float64
#  1   Price in Millions  150 non-null    float64
#  2   Square Meter       150 non-null    float64
#  3   City               150 non-null    object
# dtypes: float64(3), object(1)
# memory usage: 4.8+ KB

# %%
df.describe()
# Out:
#               Profit  Price in Millions  Square Meter
# count     150.000000         150.000000    150.000000
# mean   106126.666667          17.101933   2594.680000
# std     76413.507421           6.531691   1434.491133
# min      2000.000000           4.160000     82.000000
# 25%     45500.000000          12.890000   1499.000000
# 50%     88500.000000          17.085000   2578.500000
# 75%    137750.000000          21.760000   3628.000000
# max    250000.000000          35.350000   5741.000000

# %%
sns.countplot(df['City'])
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='City', ylabel='count'>

# %% [markdown]
# # I want show outliner

# %%
plt.boxplot(df['Profit'])
plt.show()

# %%
plt.boxplot(df['Price in Millions'])
plt.show()

# %%
plt.boxplot(df['Square Meter'])
plt.show()

# %%
plt.style.use("fivethirtyeight")
plt.figure(figsize=(20,7))
sns.lineplot(data=df,x='Square Meter',y='Profit', hue="City")
# Out:
# <AxesSubplot:xlabel='Square Meter', ylabel='Profit'>

# %%
px.scatter_3d(df,x="Square Meter",y="Profit",z="City",animation_frame="City")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.4.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %%
px.scatter_matrix(df,color="City")
# Out:
# <div>                            <div id="7a600e89-25ab-40ff-b765-08a7418184b0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7a600e89-25ab-40ff-b765-08a7418184b0")) {                    Plotly.newPlot(                        "7a600e89-25ab-40ff-b765-08a7418184b0",                        [{"dimensions":[{"axis":{"matches":true},"label":"Profit","values":[119000.0,110000.0,47000.0,124000.0,24000.0,85000.0,84000.0,63000.0,138000.0,23000.0,34000.0,18000.0,73000.0,91000.0,83000.0,87000.0,141000.0,250000.0,99000.0,121000.0,71000.0,97000.0,4000.0,126000.0,64000.0,124000.0,25000.0,19000.0,3000.0,116000.0,20000.0,39000.0,71000.0,7000.0,25000.0,44000.0,250000.0,125000.0,48000.0,192000.0,104000.0,227000.0,187000.0,250000.0,159000.0,32000.0,35000.0,90000.0]}
# ...
